# %%
import pandas as pd
import numpy as np

# %%
data = {'apples':[3,2,1,0], 'oranges':[5,4,3,2]}

# %%
purchases = pd.DataFrame(data)

purchases
# Out:
#    apples  oranges
# 0       3        5
# 1       2        4
# 2       1        3
# 3       0        2

# %%
purchases = pd.DataFrame(data, index=['a','b','c','d'])

purchases
# Out:
#    apples  oranges
# a       3        5
# b       2        4
# c       1        3
# d       0        2

# %%
# Loc -> is used to locating the index by mentioning the name
#Req: finding b's purchases

# %%
purchases.loc['b']
# Out:
# apples     2
# oranges    4
# Name: b, dtype: int64

# %%
# Reading the csv file

# %%
df = pd.read_csv('purchases.csv')
df
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
df = pd.read_csv('purchases.csv', index_col=0) # Removing index column
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
# Reading the file format - "json" file - (Java Script Object Notation) # dict-key value.

# %%
df = pd.read_json('purchases.json') ---> key value is considered. 
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
# Reading the IMDB movie dataset.

# %%
movie_df = pd.read_csv('IMDB-Movie-Data.csv')
movie_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
movie_df = pd.read_csv('IMDB-Movie-Data.csv', index_col='Title') # moving "Title has index col"
movie_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
# getting head & tail rows

# %%
movie_df = pd.read_csv('IMDB-Movie-Data.csv', index_col='Title') # getting top 5 rows)
movie_df.head(5)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movie_df = pd.read_csv('IMDB-Movie-Data.csv', index_col='Title') # getting last 3 rows)
movie_df.tail(3)
# Out:
#                         Rank                  Genre  \
# Title
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Step Up 2: The Streets        Jon M. Chu
# Search Party              Scot Armstrong
# Nine Lives              Barry Sonnenfeld
#
#                                                                    Actors  \
# Title
# Step Up 2: The Streets  Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Search Party            Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# ...

# %%
# To know overall of information of dataset.

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
# To know rows & cols.

# %%
movie_df.shape #--> shape gives (x,y) 2 dimentional structure (1000 rows & 11 cols)
# Out:
# (1000, 11)

# %%
# Handling duplicates in the data set.

# %%
temp_df = movie_df.append(movie_df) #---> Data is duplicated by adding up 1000 rows
temp_df.shape
# Out:
# (2000, 11)

# %%
# How to remove duplicates

# %%
temp_df = movie_df.drop_duplicates()
temp_df.shape
# Out:
# (1000, 11)
